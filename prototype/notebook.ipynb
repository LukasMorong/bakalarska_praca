# %%
import app
import zipfile
import json
import sys

data_file = zipfile.ZipFile('./data/data.zip', 'r')
data = json.load(data_file.open('1661426400[7]-ant121-skifiloc-ang170-iq.json', 'r'))

lens = []

# sys.stdout.write("{")
# for idx in range(624):
#     sys.stdout.write(str(data['i'][idx]))
#     sys.stdout.write(', ')
#     sys.stdout.write(str(data['q'][idx]))
#     if idx == 623:
#         break
#     sys.stdout.write(', ')
# sys.stdout.write("}")

# %% [markdown]
# ## Transformation + entropy

# %% [markdown]
# ### Not transformed, static 16bit

# %%
options = (0, 0)

compressed = app.compress(data, data['ant'], options)

lens.append(len(compressed))
print(f'Bit len: {len(compressed)}')

decompressed = app.decompress(compressed, data['ant'], options)

print(f'Same after decompress: {decompressed["i"] == data["i"] and decompressed["q"] == data["q"]}')
# Out:
# Bit len: 19968
# Same after decompress: True

# %% [markdown]
# ### Not transformed, vlq

# %%
options = (0, 1)

compressed = app.compress(data, data['ant'], options)

lens.append(len(compressed))
print(f'Bit len: {len(compressed)}')

decompressed = app.decompress(compressed, data['ant'], options)

print(f'Same after decompress: {decompressed["i"] == data["i"] and decompressed["q"] == data["q"]}')
# Out:
# Bit len: 17552
# Same after decompress: True

# %% [markdown]
# ### Not transformed, rice-golomb coding

# %%
options = (0, 2)

compressed = app.compress(data, data['ant'], options)

print(compressed)

lens.append(len(compressed))
print(f'Bit len: {len(compressed)}')

decompressed = app.decompress(compressed, data['ant'], options)

print(f'Same after decompress: {decompressed["i"] == data["i"] and decompressed["q"] == data["q"]}')
# Out:
# ...
# Bit len: 12125
# Same after decompress: True

# %% [markdown]
# ### Delta coding, vlq

# %%
options = (1, 1)

compressed = app.compress(data, data['ant'], options)

lens.append(len(compressed))
print(f'Bit len: {len(compressed)}')

decompressed = app.decompress(compressed, data['ant'], options)

print(f'Same after decompress: {decompressed["i"] == data["i"] and decompressed["q"] == data["q"]}')
# Out:
# Bit len: 14416
# Same after decompress: True

# %% [markdown]
# ### Delta coding, rice-golomb coding

# %%
options = (1, 2)

compressed = app.compress(data, data['ant'], options)

lens.append(len(compressed))
print(f'Bit len: {len(compressed)}')

decompressed = app.decompress(compressed, data['ant'], options)

print(f'Same after decompress: {decompressed["i"] == data["i"] and decompressed["q"] == data["q"]}')
# Out:
# Bit len: 10492
# Same after decompress: True

# %% [markdown]
# ### DeltaDelta coding, vlq

# %%
options = (2, 1)

compressed = app.compress(data, data['ant'], options)

lens.append(len(compressed))
print(f'Bit len: {len(compressed)}')

decompressed = app.decompress(compressed, data['ant'], options)

print(f'Same after decompress: {decompressed["i"] == data["i"] and decompressed["q"] == data["q"]}')
# Out:
# Bit len: 10176
# Same after decompress: True

# %% [markdown]
# ### DeltaDelta coding, rice-golomb coding

# %%
options = (2, 2)

compressed = app.compress(data, data['ant'], options)

lens.append(len(compressed))
print(f'Bit len: {len(compressed)}')

decompressed = app.decompress(compressed, data['ant'], options)

print(f'Same after decompress: {decompressed["i"] == data["i"] and decompressed["q"] == data["q"]}')
# Out:
# Bit len: 9065
# Same after decompress: True

# %% [markdown]
# ### Predictive coding, vlq

# %%
options = (3, 1)

# %% [markdown]
# ### Predictive coding, rice-golomb

# %%
options = (3, 2)

# %% [markdown]
# ### Predictive coding + delta, vlq

# %%
options = (4, 1)

# %% [markdown]
# ### Predictive coding + delta, rice-golomb

# %%
options = (4, 2)

# %% [markdown]
# ### Predictive coding + deltadelta, vlq

# %%
options = (5, 1)

# %% [markdown]
# ### Predictive coding + deltadelta, rice-golomb

# %%
options = (5, 2)
